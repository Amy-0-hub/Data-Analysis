# %%
from app import load_data, drop_columns, convert_cols, add_columns, build_a_dashboard, create_tab1, create_tab2, create_tab3

# %%
combine_df = load_data()
combine_df
# Out:
#        Province_State Country_Region          Last_Update      Lat     Long_  \
# 0             Alabama             US  2022-01-22 04:32:02  32.3182  -86.9023
# 1              Alaska             US  2022-01-22 04:32:02  61.3707 -152.4044
# 2      American Samoa             US  2022-01-22 04:32:02 -14.2710 -170.1320
# 3             Arizona             US  2022-01-22 04:32:02  33.7298 -111.4312
# 4            Arkansas             US  2022-01-22 04:32:02  34.9697  -92.3731
# ...               ...            ...                  ...      ...       ...
# 61609        Virginia             US  2021-06-15 04:31:17  37.7693  -78.1700
# 61610      Washington             US  2021-06-15 04:31:17  47.4009 -121.4905
# 61611   West Virginia             US  2021-06-15 04:31:17  38.4912  -80.9545
# 61612       Wisconsin             US  2021-06-15 04:31:17  44.2685  -89.6165
# 61613         Wyoming             US  2021-06-15 04:31:17  42.7560 -107.3025
#
#        Confirmed  Deaths  Recovered  Active  FIPS  ...  Total_Test_Results  \
# 0        1120881   16824        NaN     NaN   1.0  ...                 NaN
# 1         195345    1051        NaN     NaN   2.0  ...           3741734.0
# 2             18       0        NaN     NaN  60.0  ...              2140.0
# 3        1701949   25502        NaN     NaN   4.0  ...          16792390.0
# 4         726716    9484        NaN     NaN   5.0  ...           4709066.0
# ...          ...     ...        ...     ...   ...  ...                 ...
# 61609     677812   11318        NaN     NaN  51.0  ...           7553224.0
# 61610     444722    5782        NaN     NaN  53.0  ...           7358062.0
# 61611     163144    2853        NaN     NaN  54.0  ...           2972502.0
# 61612     676276    8015        NaN     NaN  55.0  ...           8893572.0
# 61613      61234     725        NaN     NaN  56.0  ...            770872.0
#
#        People_Hospitalized  Case_Fatality_Ratio         UID  ISO3  \
# 0                      NaN             1.500962  84000001.0   USA
# 1                      NaN             0.538022  84000002.0   USA
# 2                      NaN             0.000000        16.0   ASM
# 3                      NaN             1.498400  84000004.0   USA
# 4                      NaN             1.305049  84000005.0   USA
# ...                    ...                  ...         ...   ...
# 61609                  NaN             1.669785  84000051.0   USA
# 61610                  NaN             1.300138  84000053.0   USA
# 61611                  NaN             1.748762  84000054.0   USA
# 61612                  NaN             1.185167  84000055.0   USA
# 61613                  NaN             1.183983  84000056.0   USA
#
#         Testing_Rate  Hospitalization_Rate        Date People_Tested  \
# 0                NaN                   NaN  2022-01-21           NaN
# 1      511483.777485                   NaN  2022-01-21           NaN
# 2        3846.084722                   NaN  2022-01-21           NaN
# 3      230705.356452                   NaN  2022-01-21           NaN
# 4      156042.804635                   NaN  2022-01-21           NaN
# ...              ...                   ...         ...           ...
# 61609   88491.678128                   NaN  2021-06-14           NaN
# 61610   96627.253988                   NaN  2021-06-14           NaN
# 61611  165862.621760                   NaN  2021-06-14           NaN
# 61612       0.000015                   NaN  2021-06-14           NaN
# 61613  133193.954651                   NaN  2021-06-14           NaN
#
#        Mortality_Rate
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 61609             NaN
# 61610             NaN
# 61611             NaN
# 61612             NaN
# 61613             NaN
#
# [61614 rows x 21 columns]

# %%
df1 = drop_columns(combine_df)
df1
# Out:
#       Province_State      Lat     Long_  Confirmed  Deaths  Recovered  \
# 946          Indiana  39.8494  -86.2583      37397    2248    25138.0
# 952         Maryland  39.0639  -76.8021      57973    2749     4240.0
# 958          Montana  46.9219 -110.4544        545      18      475.0
# 964         New York  42.1657  -74.9481     378097   30219    67544.0
# 975     South Dakota  44.2998  -99.4388       5438      65     4335.0
# ...              ...      ...       ...        ...     ...        ...
# 60941       Maryland  39.0639  -76.8021      16616     798     1108.0
# 60943       Michigan  43.3266  -84.5361      36641    3085     3237.0
# 60947        Montana  46.9219 -110.4544        444      14      325.0
# 60953       New York  42.1657  -74.9481     271590   21327    23887.0
# 60965   South Dakota  44.2998  -99.4388       2040      10     1190.0
#
#          Active  FIPS  Incident_Rate  Total_Test_Results  People_Hospitalized  \
# 946     10011.0  18.0     555.492921            386499.0               6136.0
# 952     50984.0  24.0     958.916119            421554.0               9546.0
# 958        52.0  30.0      50.992816             47378.0                 69.0
# 964    280334.0  36.0    1943.587603           2497842.0              89995.0
# 975      1038.0  46.0     614.700127             63241.0                478.0
# ...         ...   ...            ...                 ...                  ...
# 60941   14710.0  24.0     274.840878             94203.0               3618.0
# 60943   30319.0  26.0     366.892206            169942.0               3022.0
# 60947     105.0  30.0      41.542771             12127.0                 59.0
# 60953  226376.0  36.0    1396.094011            730656.0              57103.0
# 60965     840.0  46.0     230.597326             15030.0                124.0
#
#        Testing_Rate        Date  People_Tested  Mortality_Rate
# 946    5.741034e-07  2020-06-07       304263.0        6.011177
# 952    6.972814e-07  2020-06-07       364803.0        4.741863
# 958    4.432913e+03  2020-06-07        47378.0        3.302752
# 964    1.284002e+04  2020-06-07      2497842.0        7.992393
# 975    7.148630e-07  2020-06-07        57060.0        1.195292
# ...             ...         ...            ...             ...
# 60941  1.558187e-07  2020-04-24        84716.0        4.802600
# 60943  1.701656e-07  2020-04-24       136296.0        8.419530
# 60947  1.134660e+03  2020-04-24        12127.0        3.153153
# 60953  3.755898e+03  2020-04-24       730656.0        7.852646
# 60965  1.698960e-07  2020-04-24        14824.0        0.490196
#
# [915 rows x 15 columns]

# %%
df2 = convert_cols(df1)
df2.dtypes
# Out:
# Province_State                 object
# Lat                           float64
# Long_                         float64
# Confirmed                       int64
# Deaths                          int64
# Recovered                     float64
# Active                        float64
# FIPS                          float64
# Incident_Rate                 float64
# Total_Test_Results            float64
# People_Hospitalized           float64
# Testing_Rate                  float64
# Date                   datetime64[ns]
# People_Tested                 float64
# Mortality_Rate                float64
# dtype: object

# %%
df3, df_test_confirm1 = add_columns(df2)
print(f'df3,\n{df3[['Stage', 'State_Abbr']]}')
# Out:
# df3,
#            Stage State_Abbr
# 0    Early Stage         DE
# 1    Early Stage         DE
# 2    Early Stage         DE
# 3    Early Stage         DE
# 4    Early Stage         DE
# ..           ...        ...
# 910   Last Stage         WI
# 911   Last Stage         WI
# 912   Last Stage         WI
# 913   Last Stage         WI
# 914   Last Stage         WI
#
# [915 rows x 2 columns]

# %%
print(f'df_test_confirm1, \n{df_test_confirm1}')
# Out:
# df_test_confirm1,
#           Date  Total_Test_Results  Confirmed Province_State
# 0   2020-04-12             17870.0       1625       Delaware
# 1   2020-04-13             18586.0       1758       Delaware
# 2   2020-04-14             19302.0       1926       Delaware
# 3   2020-04-15             20276.0       2014       Delaware
# 4   2020-04-16             21069.0       2070       Delaware
# ..         ...                 ...        ...            ...
# 910 2020-08-23           1616301.0      70462      Wisconsin
# 911 2020-08-24           1629764.0      70854      Wisconsin
# 912 2020-08-25           1639656.0      71492      Wisconsin
# 913 2020-08-26           1657496.0      72260      Wisconsin
# 914 2020-08-27           1675074.0      73138      Wisconsin
#
# [915 rows x 4 columns]

# %%
choose_state1, choose_stage1, state_options1, stage_options1, df_test_confirm_state_option1, tab11, tab21, tab31= build_a_dashboard(df3, df_test_confirm1)
# Out:
# 2025-06-11 15:09:16.253 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.349
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/yaqin/py/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-06-11 15:09:16.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.352 Session state does not function when running a script without `streamlit run`
# 2025-06-11 15:09:16.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:16.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
create_tab1(tab11, choose_state1, state_options1)
# Out:
# 2025-06-11 15:09:19.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:19.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:19.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:19.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:19.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
create_tab2(tab21, choose_stage1, stage_options1)
# Out:
# 2025-06-11 15:09:22.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:22.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:22.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:22.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:22.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:22.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
create_tab3(tab31, choose_state1, df_test_confirm_state_option1)
# Out:
# 2025-06-11 15:09:26.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:26.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:26.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:26.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:09:26.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
